# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("eurovision_2016-25.csv", encoding="latin1")

# %%
df
# Out:
#      Year        Country                  Song               Artist   \
# 0    2025         Albania                 Zjerm  Shkodra Elektronike
# 1    2025         Armenia              Survivor                 Parg
# 2    2025       Australia         Milkshake Man                Go-Jo
# 3    2025         Austria           Wasted Love                   JJ
# 4    2025      Azerbaijan            Run with U             Mamagama
# ..    ...             ...                   ...                  ...
# 353  2016           Spain              Say Yay!                Barei
# 354  2016          Sweden       If I Were Sorry                Frans
# 355  2016     Switzerland  The Last Of Our Kind                Rykka
# 356  2016         Ukraine                  1944               Jamala
# 357  2016  United Kingdom      You're Not Alone         Joe and Jake
#
#      Final_Place  Final_Points  Top 5  Top 10  Running_Order_Final  \
# 0            NaN           NaN    NaN     NaN                  NaN
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Country ', 'Song ', 'Artist ', 'Final_Place', 'Final_Points',
#        'Top 5', 'Top 10', 'Running_Order_Final', 'Grand_Final_Ind', 'Big6_Ind',
#        'Semi_Final_Num', 'Semi_Place', 'Semi_Points', 'Running_Order_Semi',
#        'National_Final', 'Solo_Artist', 'Sex', 'Returning_Artist_Ind',
#        'Number of Members', 'Language1', 'Language2', 'Language3', 'Language4',
#        'Multiple_Language', 'National_Language_Used', 'EU', 'NATO',
#        'Country_Group', 'MyESB_Community', 'MyESB_Personal', 'OGAE_Points',
#        'Qualification_Record'],
#       dtype='object')

# %%
#Seleccionamos las columnas que nos interesan: 

df= df[['Year','Country ','Song ', 'Artist ', 'Final_Place', 'Final_Points', 'Big6_Ind',
   'Solo_Artist', 'Sex', 'Number of Members', 'Language1',
       'Multiple_Language', 'National_Language_Used', 'EU', 'NATO',
       'Country_Group', 'MyESB_Community', 'OGAE_Points']]

# %%
df
# Out:
#      Year        Country                  Song               Artist   \
# 0    2025         Albania                 Zjerm  Shkodra Elektronike
# 1    2025         Armenia              Survivor                 Parg
# 2    2025       Australia         Milkshake Man                Go-Jo
# 3    2025         Austria           Wasted Love                   JJ
# 4    2025      Azerbaijan            Run with U             Mamagama
# ..    ...             ...                   ...                  ...
# 353  2016           Spain              Say Yay!                Barei
# 354  2016          Sweden       If I Were Sorry                Frans
# 355  2016     Switzerland  The Last Of Our Kind                Rykka
# 356  2016         Ukraine                  1944               Jamala
# 357  2016  United Kingdom      You're Not Alone         Joe and Jake
#
#      Final_Place  Final_Points  Big6_Ind  Solo_Artist    Sex  \
# 0            NaN           NaN         0            0  Mixed
# ...

# %%
# Exploratory Data Analysis (EDA):
# Examinar y visualizar los datos de manera sistemática con el objetivo de descubrir patrones,
# identificar tendencias, detectar valores atípicos y extraer información relevante.

def eda_basico(df):
    print("🔍 Primeras filas del DataFrame:")
    display(df.head())
    print("📐 Dimensiones:")
    print(df.shape , "\n")
    print("🧠 Información general:")
    display(df.info())
    print('🌑Nombre de las columnas:')
    display(df.columns)
    print("📊 Tipos de datos por columna:")
    print(df.dtypes, "\n")
    print("📉 Descripción de columnas numéricas:")
    display(df.describe())
    print("🔤 Descripción de columnas categóricas:")
    if any(df.dtypes == 'O'):
        display(df.describe(include=['O']))
    print("🚫 Valores nulos por columna:")
    display(df.isnull().sum())
    print("🚫 Porcentaje de nulos por columna:")
    display(((df.isnull().sum()/df.shape[0])*100).round(2))
  
    print("📎 Filas duplicadas:")
    dup_count = df.duplicated().sum()
    print(f"Duplicadas: {dup_count}")
    if dup_count > 0:
        print("Ejemplo de duplicados:")
        print(df[df.duplicated()].head(), "\n")
    else:
        print("No hay filas duplicadas.\n")

# %%
eda_basico(df)
# Out:
# 🔍 Primeras filas del DataFrame:
#    Year    Country           Song               Artist   Final_Place  \
# 0  2025     Albania          Zjerm  Shkodra Elektronike          NaN
# 1  2025     Armenia       Survivor                 Parg          NaN
# 2  2025   Australia  Milkshake Man                Go-Jo          NaN
# 3  2025     Austria    Wasted Love                   JJ          NaN
# 4  2025  Azerbaijan     Run with U             Mamagama          NaN
#
#    Final_Points  Big6_Ind  Solo_Artist    Sex  Number of Members Language1  \
# 0           NaN         0            0  Mixed                  2  Albanian
# 1           NaN         0            1     M                   1   English
# 2           NaN         0            1      M                  1   English
# 3           NaN         0            1      M                  1   English
# 4           NaN         0            0      M                  3   English
#
# ...

# %%
# IMPUTAMOS LOS NULOS:
# Cambiamos el tipo de dato a object:
df[['Final_Place','Final_Points']] = df[['Final_Place','Final_Points']].astype(object)
# Out:
# C:\Users\almue\AppData\Local\Temp\ipykernel_24116\3649703815.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Final_Place','Final_Points']] = df[['Final_Place','Final_Points']].astype(object)

# %%
# Comprobamos el tipo de dato:
df[['Final_Place','Final_Points']].dtypes
# Out:
# Final_Place     object
# Final_Points    object
# dtype: object

# %%
# Imputamos los nulos: 
df[['Final_Place','Final_Points']]= df[['Final_Place','Final_Points']].fillna('No clasifica')
# Out:
# C:\Users\almue\AppData\Local\Temp\ipykernel_24116\2866824284.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Final_Place','Final_Points']]= df[['Final_Place','Final_Points']].fillna('No clasifica')

# %%
# Comprobamos: 
df[['Final_Place','Final_Points']].isnull().sum()
# Out:
# Final_Place     0
# Final_Points    0
# dtype: int64

# %%
df
# Out:
#      Year        Country                  Song               Artist   \
# 0    2025         Albania                 Zjerm  Shkodra Elektronike
# 1    2025         Armenia              Survivor                 Parg
# 2    2025       Australia         Milkshake Man                Go-Jo
# 3    2025         Austria           Wasted Love                   JJ
# 4    2025      Azerbaijan            Run with U             Mamagama
# ..    ...             ...                   ...                  ...
# 353  2016           Spain              Say Yay!                Barei
# 354  2016          Sweden       If I Were Sorry                Frans
# 355  2016     Switzerland  The Last Of Our Kind                Rykka
# 356  2016         Ukraine                  1944               Jamala
# 357  2016  United Kingdom      You're Not Alone         Joe and Jake
#
#       Final_Place  Final_Points  Big6_Ind  Solo_Artist    Sex  \
# 0    No clasifica  No clasifica         0            0  Mixed
# ...

# %%
# Guardamos en un CSV: 
df.to_csv('eurovision_limpio.csv', index= False, encoding = 'utf-8')
